# %% [markdown]
# <a href="https://colab.research.google.com/github/jperala/Test/blob/main/LinearRegression_with_Scikit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Generate synthetic data
np.random.seed(42)
x = 2 * np.random.rand(100, 1) - 1  # Random x values between -1 and 1
y = x**2 + np.random.randn(100, 1) * 0.1  # y = x^2 + noise

# Plot the generated data
plt.scatter(x, y, s=50, c='blue', label='Data points')
plt.title('Synthetic Data: y = x^2 + noise')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend()
plt.show()

# Linear Regression
X = x.reshape(-1, 1)
reg = LinearRegression()
reg.fit(X, y)
y_pred = reg.predict(X)

# Plot the data along with the regression line
plt.scatter(x, y, s=50, c='blue', label='Data points')
plt.plot(x, y_pred, color='red', label='Regression Line')
plt.title('Linear Regression on Synthetic Data')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend()
plt.show()

# Calculate MSE
mse = mean_squared_error(y, y_pred)
print(f"Mean Squared Error: {mse:.2f}")
# Out:
# Mean Squared Error: 0.11

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Generate synthetic data
np.random.seed(42) #We can put a random number helps us to generate the random number.
N=100 #Number of instances
x = 2 * np.random.rand(N, 1) - 1  # Random x values between -1 and 1
noise = np.random.rand(N,1)-*0.2-0.1 # noise will range -.1 to 0.1
r = 3*x + 5 + np.random.randn(100, 1) * 0.1

# %%
# Out:
# array([[0.17711068, 0.94045858, 0.95392858, 0.91486439],
#        [0.3701587 , 0.01545662, 0.92831856, 0.42818415],
#        [0.96665482, 0.96361998, 0.85300946, 0.29444889],
#        [0.38509773, 0.85113667, 0.31692201, 0.16949275],
#        [0.55680126, 0.93615477, 0.6960298 , 0.57006117],
#        [0.09717649, 0.61500723, 0.99005385, 0.14008402],
#        [0.51832965, 0.87737307, 0.74076862, 0.69701574],
#        [0.70248408, 0.35949115, 0.29359184, 0.80936116],
#        [0.81011339, 0.86707232, 0.91324055, 0.5113424 ],
#        [0.50151629, 0.79829518, 0.64996393, 0.70196688],
#        [0.79579267, 0.89000534, 0.33799516, 0.37558295],
#        [0.09398194, 0.57828014, 0.03594227, 0.46559802],
#        [0.54264463, 0.28654125, 0.59083326, 0.03050025],
#        [0.03734819, 0.82260056, 0.36019064, 0.12706051],
#        [0.52224326, 0.76999355, 0.21582103, 0.62289048],
#        [0.08534746, 0.05168172, 0.53135463, 0.54063512],
# ...

# %%
# Create a new feature matrix including x and x^2
X = np.hstack([x**2, x])

# Fit a linear regression model using x and x^2 as features
reg_poly = LinearRegression()
reg_poly.fit(X, y)
y_pred_poly = reg_poly.predict(X)

# Plot the data along with the regression curve
plt.scatter(x, y, s=50, c='blue', label='Data points')
sorted_order = np.argsort(x[:, 0])
plt.plot(x[sorted_order], y_pred_poly[sorted_order], color='green', label='Regression Curve with x^2 feature')
plt.title('Linear Regression with x and x^2 as Features')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend()
plt.show()

# Calculate MSE
mse_poly = mean_squared_error(y, y_pred_poly)
print(f"Mean Squared Error with x^2 feature: {mse_poly:.2f}")
# Out:
# Mean Squared Error with x^2 feature: 0.01
